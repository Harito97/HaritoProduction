# %%
# %cd /Data/Projects/HaritoProduction
from backend.app.H97_ThyroidCancer import H97_ThyroidCancer
import numpy as np
import torch
# Out:
# /Data/Projects/venv_manager/ai_work#311/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /Data/Projects/HaritoProduction

# %%
app = H97_ThyroidCancer()
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.

# %%
image_origin_dir = '/Data/Projects/ThyroidCancer/Phase1/Data/origin_data/B256/B6/Image_26389.jpg'
predicted, output_model3, output_model2, patch_level_heatmap, image_level_heatmap, yolo_detect_image = app.main(image_origin_dir)
# Out:
# Loading /Data/Projects/HaritoProduction/backend/app/models/cell_cluster_detect_300_epoches_best.onnx for ONNX Runtime inference...
#
# image 1/1 /Data/Projects/ThyroidCancer/Phase1/Data/origin_data/B256/B6/Image_26389.jpg: 640x640 10 clusters, 56.5ms
# Speed: 3.3ms preprocess, 56.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# /Data/Projects/ThyroidCancer/Phase1/Data/origin_data/B256/B6/Image_26389.jpg have 10 cell importance clusters
# <class 'numpy.ndarray'> (18, 224, 224, 3) float64
# <class 'torch.Tensor'> torch.Size([18, 1280, 7, 7]) torch.float32
# torch.Size([18, 1280, 7, 7]) torch.float32
# torch.Size([1280]) torch.float32
# torch.Size([18, 49])
# torch.Size([18, 1280, 49])
# torch.Size([18, 7, 7])
# torch.Size([18, 7, 7])
# <class 'torch.Tensor'> torch.Size([1, 3]) torch.float32

# %%
print(predicted, output_model3, output_model2.shape)
import matplotlib.pyplot as plt
import numpy as np
import cv2
# image_rgb = cv2.cvtColor(yolo_detect_image, cv2.COLOR_BGR2RGB)
image_rgb = yolo_detect_image
plt.imshow(image_rgb,)
plt.title('Detect image')
plt.axis('off')  # Ẩn các trục
plt.show()
# Out:
# tensor([2]) tensor([[7.9506e-25, 8.6528e-27, 1.0000e+00]], grad_fn=<SoftmaxBackward0>) torch.Size([18, 3])

# %%
plt.imshow(patch_level_heatmap,)
plt.title('Patch Level Image')
plt.axis('off')  # Ẩn các trục
plt.show()

# %%
plt.imshow(image_level_heatmap,)
plt.title('Image Level Image')
plt.axis('off')  # Ẩn các trục
plt.show()
