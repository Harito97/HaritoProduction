# %%
# %cd /Data/Projects/HaritoProduction
from backend.app.H97ThyroidCancer import H97ThyroidCancer
import numpy as np
import torch
# Out:
# /Data/Projects/venv_manager/ai_work#311/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /Data/Projects/HaritoProduction

# %%
app = H97ThyroidCancer()
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.

# %%
image_origin_dir = '/Data/Projects/ThyroidCancer/Phase1/Data/origin_data/B256/B6/Image_26389.jpg'

# cam_on_images, output_model2, grayscale_cams, yolo_detect_image, images = app.run(image_origin_dir)

# %%
# Gọi hàm run để lấy kết quả
app.run(image_origin_dir, use_rgb=False)
# Out:
# image 1/1 /Data/Projects/ThyroidCancer/Phase1/Data/origin_data/B256/B6/Image_26389.jpg: 640x640 10 clusters, 77.8ms
# Speed: 2.3ms preprocess, 77.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# /Data/Projects/ThyroidCancer/Phase1/Data/origin_data/B256/B6/Image_26389.jpg have 10 cell importance clusters
# Image i th: 0
# Image i th: 1
# Image i th: 2
# Image i th: 3
# Image i th: 4
# Image i th: 5
# Image i th: 6
# Image i th: 7
# Image i th: 8
# Image i th: 9
# Image i th: 10
# Image i th: 11
# Image i th: 12
# Image i th: 13
# Image i th: 14
# Image i th: 15
# Image i th: 16
# Image i th: 17

# %%
app.output_model2
# Out:
# [tensor([[-222.7341,  -20.5380,  -12.9541]], grad_fn=<AddmmBackward0>),
#  tensor([[-363.3455,  -33.5729,  -21.0145]], grad_fn=<AddmmBackward0>),
#  tensor([[-967.2109,  -89.5509,  -55.6298]], grad_fn=<AddmmBackward0>),
#  tensor([[-128.3726,  -11.7177,   -7.4951]], grad_fn=<AddmmBackward0>),
#  tensor([[-198.4308,  -18.2788,  -11.5566]], grad_fn=<AddmmBackward0>),
#  tensor([[-1143.9911,  -105.9384,   -65.7634]], grad_fn=<AddmmBackward0>),
#  tensor([[-146.6676,    0.9558,    1.2752]], grad_fn=<AddmmBackward0>),
#  tensor([[-478.8060,  -44.2758,  -27.6329]], grad_fn=<AddmmBackward0>),
#  tensor([[-609.6072,  -56.4011,  -35.1309]], grad_fn=<AddmmBackward0>),
#  tensor([[-844.2843,  -78.1557,  -48.5833]], grad_fn=<AddmmBackward0>),
#  tensor([[-692.1110,  -64.0493,  -39.8603]], grad_fn=<AddmmBackward0>),
#  tensor([[-456.0381,  -42.1653,  -26.3279]], grad_fn=<AddmmBackward0>),
#  tensor([[-117.7303,   -4.7131,   -2.7728]], grad_fn=<AddmmBackward0>),
# ...

# %%
# app.plot_results(cam_on_images, output_model2, grayscale_cams, yolo_detect_image, images)

# %%
from backend.utils.image import read_images, plot_heatmap
plot_heatmap(app.get_analyst_image1())
plot_heatmap(app.get_analyst_image2(),)
plot_heatmap(app.get_analyst_image3(), reversed=True)

# %%
app.output_model2
# Out:
# [tensor([[-222.7341,  -20.5380,  -12.9541]], grad_fn=<AddmmBackward0>),
#  tensor([[-363.3455,  -33.5729,  -21.0145]], grad_fn=<AddmmBackward0>),
#  tensor([[-967.2109,  -89.5509,  -55.6298]], grad_fn=<AddmmBackward0>),
#  tensor([[-128.3726,  -11.7177,   -7.4951]], grad_fn=<AddmmBackward0>),
#  tensor([[-198.4308,  -18.2788,  -11.5566]], grad_fn=<AddmmBackward0>),
#  tensor([[-1143.9911,  -105.9384,   -65.7634]], grad_fn=<AddmmBackward0>),
#  tensor([[-146.6676,    0.9558,    1.2752]], grad_fn=<AddmmBackward0>),
#  tensor([[-478.8060,  -44.2758,  -27.6329]], grad_fn=<AddmmBackward0>),
#  tensor([[-609.6072,  -56.4011,  -35.1309]], grad_fn=<AddmmBackward0>),
#  tensor([[-844.2843,  -78.1557,  -48.5833]], grad_fn=<AddmmBackward0>),
#  tensor([[-692.1110,  -64.0493,  -39.8603]], grad_fn=<AddmmBackward0>),
#  tensor([[-456.0381,  -42.1653,  -26.3279]], grad_fn=<AddmmBackward0>),
#  tensor([[-117.7303,   -4.7131,   -2.7728]], grad_fn=<AddmmBackward0>),
# ...

# %%
max_labels = [tensor.argmax(dim=1).item() for tensor in app.output_model2]

print(max_labels)
# Out:
# [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2]
